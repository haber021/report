# %%
import pandas as pd

# Load data into a DataFrame
df = pd.read_csv('DOH COVID Data Drop_ 20240103 (2020-2023) - 04 Case Information_batch_3.csv')

# %%
df.head()
# Out:
#     CaseCode   Age  AgeGroup     Sex DateSpecimen DateResultRelease  \
# 0  C52396674  38.0  35 to 39    MALE   2022-01-10        2022-01-11
# 1  C56330302  26.0  25 to 29    MALE   2022-01-05        2022-01-05
# 2  C90544550  81.0       80+  FEMALE   2022-01-10        2022-01-11
# 3  C91650768  31.0  30 to 34    MALE   2022-01-10        2022-01-11
# 4  C27787853   1.0    0 to 4  FEMALE   2022-01-10        2022-01-11
#
#   DateRepConf DateDied DateRecover RemovalType  ...  ProvRes  \
# 0  2022-01-13      NaN         NaN   RECOVERED  ...  BULACAN
# 1  2022-01-13      NaN         NaN   RECOVERED  ...  BULACAN
# 2  2022-01-13      NaN         NaN   RECOVERED  ...      NCR
# 3  2022-01-13      NaN         NaN   RECOVERED  ...      NCR
# 4  2022-01-13      NaN         NaN   RECOVERED  ...      NCR
#
#            CityMunRes CityMuniPSGC  BarangayRes BarangayPSGC HealthStatus  \
# 0  CITY OF MEYCAUAYAN  PH031412000     MALHACAN  PH031412015    RECOVERED
# ...

# %%
df.shape
# Out:
# (1000000, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 23 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   CaseCode           1000000 non-null  object
#  1   Age                991639 non-null   float64
#  2   AgeGroup           991639 non-null   object
#  3   Sex                999999 non-null   object
#  4   DateSpecimen       790582 non-null   object
#  5   DateResultRelease  792113 non-null   object
#  6   DateRepConf        1000000 non-null  object
#  7   DateDied           6759 non-null     object
#  8   DateRecover        184901 non-null   object
#  9   RemovalType        999789 non-null   object
#  10  DateRepRem         999789 non-null   object
#  11  Admitted           968946 non-null   object
#  12  RegionRes          999491 non-null   object
#  13  ProvRes            986285 non-null   object
#  14  CityMunRes         965942 non-null   object
# ...

# %%
df['Age'] = pd.to_numeric(df['Age'],errors= 'coerce').astype('Int64')

# %%
df['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000000 entries, 0 to 999999
# Series name: Age
# Non-Null Count   Dtype
# --------------   -----
# 991639 non-null  Int64
# dtypes: Int64(1)
# memory usage: 8.6 MB

# %%
df_data = df[(df['CityMunRes'] == 'BACNOTAN')] #& (df['Sex'] == 'MALE')
df_data.head()
# Out:
#        CaseCode  Age  AgeGroup     Sex DateSpecimen DateResultRelease  \
# 121   C57939301   28  25 to 29  FEMALE          NaN               NaN
# 2736  C54910590    7    5 to 9  FEMALE          NaN               NaN
# 4664  C16783710   23  20 to 24    MALE          NaN               NaN
# 5051  C69731082   53  50 to 54  FEMALE   2022-01-10        2022-01-12
# 8528  C43503348   69  65 to 69  FEMALE   2022-01-10        2022-01-12
#
#      DateRepConf DateDied DateRecover RemovalType  ...   ProvRes CityMunRes  \
# 121   2022-01-13      NaN         NaN   RECOVERED  ...  LA UNION   BACNOTAN
# 2736  2022-01-13      NaN         NaN   RECOVERED  ...  LA UNION   BACNOTAN
# 4664  2022-01-13      NaN         NaN   RECOVERED  ...  LA UNION   BACNOTAN
# 5051  2022-01-13      NaN         NaN   RECOVERED  ...  LA UNION   BACNOTAN
# 8528  2022-01-13      NaN         NaN   RECOVERED  ...  LA UNION   BACNOTAN
#
#      CityMuniPSGC BarangayRes BarangayPSGC HealthStatus Quarantined  \
# ...

# %%
df_data.shape# This checks how many missing values each column has.
# Out:
# (476, 23)

# %%
# Drop rows where either 'Age' or 'AgeGroup' have missing values
df_data_cleaned = df_data.dropna(subset=['Age', 'AgeGroup'])

# %%
# df_cleaned = df.drop(['DateDied'], axis=1)

# %%
df_data['DateOnset'] = pd.to_datetime(df_data['DateOnset'], errors='coerce')
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\1454993844.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DateOnset'] = pd.to_datetime(df_data['DateOnset'], errors='coerce')

# %%
df_data['DateOnset'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 476 entries, 121 to 997060
# Series name: DateOnset
# Non-Null Count  Dtype
# --------------  -----
# 304 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 7.4 KB

# %%
df_data['DateOnset'].fillna(df_data['DateOnset'].median(), inplace=True)
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\3450197108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DateOnset'].fillna(df_data['DateOnset'].median(), inplace=True)

# %%
df_mode = df_data['DateOnset'].median()
print(df_mode)
# Out:
# 2022-01-19 00:00:00

# %%
df_data_cleaned.isnull().sum()
# Out:
# CaseCode               0
# Age                    0
# AgeGroup               0
# Sex                    0
# DateSpecimen         165
# DateResultRelease    164
# DateRepConf            0
# DateDied             472
# DateRecover          473
# RemovalType            0
# DateRepRem             0
# Admitted               9
# RegionRes              0
# ProvRes                0
# CityMunRes             0
# CityMuniPSGC           0
# BarangayRes            3
# BarangayPSGC           3
# HealthStatus           0
# Quarantined            0
# DateOnset            172
# Pregnanttab          204
# ValidationStatus       1
# dtype: int64

# %%
df_data['DateRecover'] = pd.to_datetime(df_data['DateRecover'], errors='coerce')
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\1743905230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DateRecover'] = pd.to_datetime(df_data['DateRecover'], errors='coerce')

# %%
df_data['DateRecover'].median()
# Out:
# Timestamp('2022-01-19 00:00:00')

# %%
df_data['DateDied'].fillna('unkown', inplace=True)
df_data['DateRecover'].fillna(df_data['DateRecover'].median(), inplace=True)
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\3215262080.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DateDied'].fillna('unkown', inplace=True)
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\3215262080.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DateRecover'].fillna(df_data['DateRecover'].median(), inplace=True)

# %%
df_data[['DateDied','DateRecover']].head()
# Out:
#      DateDied DateRecover
# 121    unkown  2022-01-19
# 2736   unkown  2022-01-19
# 4664   unkown  2022-01-19
# 5051   unkown  2022-01-19
# 8528   unkown  2022-01-19

# %%
df_data['RemovalType'].fillna(df_data['RemovalType'].mode()[0], inplace=True)
df_data['Pregnanttab'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\84244620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['RemovalType'].fillna(df_data['RemovalType'].mode()[0], inplace=True)
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\84244620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Pregnanttab'].fillna('Unknown', inplace=True)

# %%
df_data['RemovalType'].mode()
print(df_mode)
# Out:
# 2022-01-19 00:00:00

# %%
df_data.isnull().sum()
# Out:
# CaseCode               0
# Age                    1
# AgeGroup               1
# Sex                    0
# DateSpecimen         165
# DateResultRelease    164
# DateRepConf            0
# DateDied               0
# DateRecover            0
# RemovalType            0
# DateRepRem             0
# Admitted               9
# RegionRes              0
# ProvRes                0
# CityMunRes             0
# CityMuniPSGC           0
# BarangayRes            3
# BarangayPSGC           3
# HealthStatus           0
# Quarantined            0
# DateOnset              0
# Pregnanttab            0
# ValidationStatus       1
# dtype: int64

# %%
df_data['DateSpecimen'].fillna(df_data['DateSpecimen'].mode()[0], inplace=True)
df_data['DateResultRelease'].fillna(df_data['DateResultRelease'].mode()[0], inplace=True)
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\1630758024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DateSpecimen'].fillna(df_data['DateSpecimen'].mode()[0], inplace=True)
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\1630758024.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DateResultRelease'].fillna(df_data['DateResultRelease'].mode()[0], inplace=True)

# %%
df_data[['DateSpecimen','DateResultRelease']].mode()
# Out:
#   DateSpecimen DateResultRelease
# 0   2022-01-17        2022-01-21

# %%
df_data.isnull().sum()
# Out:
# CaseCode             0
# Age                  1
# AgeGroup             1
# Sex                  0
# DateSpecimen         0
# DateResultRelease    0
# DateRepConf          0
# DateDied             0
# DateRecover          0
# RemovalType          0
# DateRepRem           0
# Admitted             9
# RegionRes            0
# ProvRes              0
# CityMunRes           0
# CityMuniPSGC         0
# BarangayRes          3
# BarangayPSGC         3
# HealthStatus         0
# Quarantined          0
# DateOnset            0
# Pregnanttab          0
# ValidationStatus     1
# dtype: int64

# %%
df_data['Admitted'].fillna('No', inplace=True)
df_data['ValidationStatus'].fillna('Unvalidated', inplace=True)
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\2538853271.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Admitted'].fillna('No', inplace=True)
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\2538853271.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['ValidationStatus'].fillna('Unvalidated', inplace=True)

# %%
df_data.isnull().sum()
# Out:
# CaseCode             0
# Age                  1
# AgeGroup             1
# Sex                  0
# DateSpecimen         0
# DateResultRelease    0
# DateRepConf          0
# DateDied             0
# DateRecover          0
# RemovalType          0
# DateRepRem           0
# Admitted             0
# RegionRes            0
# ProvRes              0
# CityMunRes           0
# CityMuniPSGC         0
# BarangayRes          3
# BarangayPSGC         3
# HealthStatus         0
# Quarantined          0
# DateOnset            0
# Pregnanttab          0
# ValidationStatus     0
# dtype: int64

# %%
df_data[['Admitted','ValidationStatus']].head()
# Out:
#      Admitted                                   ValidationStatus
# 121        NO  Removal Type is "Recovered", but no Recovered ...
# 2736       NO  Removal Type is "Recovered", but no Recovered ...
# 4664       NO  Case has Lab Result, but Result Date is blank\...
# 5051       NO  Removal Type is "Recovered", but no Recovered ...
# 8528       NO  Removal Type is "Recovered", but no Recovered ...

# %%
df_data['BarangayRes'].fillna(df_data['BarangayRes'].mode()[0], inplace=True)
df_data['BarangayPSGC'].fillna(df_data['BarangayPSGC'].mode()[0], inplace=True)
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\2890210357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['BarangayRes'].fillna(df_data['BarangayRes'].mode()[0], inplace=True)
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\2890210357.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['BarangayPSGC'].fillna(df_data['BarangayPSGC'].mode()[0], inplace=True)

# %%
df_data[['BarangayRes','BarangayPSGC']].mode()
# Out:
#   BarangayRes BarangayPSGC
# 0   POBLACION  PH013303034

# %%
df_data.isnull().sum()
# Out:
# CaseCode             0
# Age                  1
# AgeGroup             1
# Sex                  0
# DateSpecimen         0
# DateResultRelease    0
# DateRepConf          0
# DateDied             0
# DateRecover          0
# RemovalType          0
# DateRepRem           0
# Admitted             0
# RegionRes            0
# ProvRes              0
# CityMunRes           0
# CityMuniPSGC         0
# BarangayRes          0
# BarangayPSGC         0
# HealthStatus         0
# Quarantined          0
# DateOnset            0
# Pregnanttab          0
# ValidationStatus     0
# dtype: int64

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 476 entries, 121 to 997060
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CaseCode           476 non-null    object
#  1   Age                475 non-null    Int64
#  2   AgeGroup           475 non-null    object
#  3   Sex                476 non-null    object
#  4   DateSpecimen       476 non-null    object
#  5   DateResultRelease  476 non-null    object
#  6   DateRepConf        476 non-null    object
#  7   DateDied           476 non-null    object
#  8   DateRecover        476 non-null    datetime64[ns]
#  9   RemovalType        476 non-null    object
#  10  DateRepRem         476 non-null    object
#  11  Admitted           476 non-null    object
#  12  RegionRes          476 non-null    object
#  13  ProvRes            476 non-null    object
#  14  CityMunRes         476 non-null    object
#  15  CityMuniPSGC       476 non-null    object
# ...

# %%
df_data['AgeGroup'].astype('category')
# Out:
# 121       25 to 29
# 2736        5 to 9
# 4664      20 to 24
# 5051      50 to 54
# 8528      65 to 69
#             ...
# 963816    55 to 59
# 972876    20 to 24
# 981024    25 to 29
# 996933    30 to 34
# 997060    30 to 34
# Name: AgeGroup, Length: 476, dtype: category
# Categories (17, object): ['0 to 4', '10 to 14', '15 to 19', '20 to 24', ..., '65 to 69', '70 to 74', '75 to 79', '80+']

# %%
df_data['AgeGroup'].mode()
# Out:
# 0    25 to 29
# Name: AgeGroup, dtype: object

# %%
df_data['AgeGroup'].isnull().sum()
# Out:
# 1

# %%
df_data['AgeGroup'].fillna(df['AgeGroup'].mode()[0], inplace=True)
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\3337302980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['AgeGroup'].fillna(df['AgeGroup'].mode()[0], inplace=True)

# %%
df_data.isnull().sum()
# Out:
# CaseCode             0
# Age                  1
# AgeGroup             0
# Sex                  0
# DateSpecimen         0
# DateResultRelease    0
# DateRepConf          0
# DateDied             0
# DateRecover          0
# RemovalType          0
# DateRepRem           0
# Admitted             0
# RegionRes            0
# ProvRes              0
# CityMunRes           0
# CityMuniPSGC         0
# BarangayRes          0
# BarangayPSGC         0
# HealthStatus         0
# Quarantined          0
# DateOnset            0
# Pregnanttab          0
# ValidationStatus     0
# dtype: int64

# %%
df_data['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 476 entries, 121 to 997060
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 475 non-null    Int64
# dtypes: Int64(1)
# memory usage: 7.9 KB

# %%
df_data['Age'].fillna(df_data['Age'].mean().astype(int), inplace=True)
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\3947903623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Age'].fillna(df_data['Age'].mean().astype(int), inplace=True)

# %%
df_data.isnull().sum()
# Out:
# CaseCode             0
# Age                  0
# AgeGroup             0
# Sex                  0
# DateSpecimen         0
# DateResultRelease    0
# DateRepConf          0
# DateDied             0
# DateRecover          0
# RemovalType          0
# DateRepRem           0
# Admitted             0
# RegionRes            0
# ProvRes              0
# CityMunRes           0
# CityMuniPSGC         0
# BarangayRes          0
# BarangayPSGC         0
# HealthStatus         0
# Quarantined          0
# DateOnset            0
# Pregnanttab          0
# ValidationStatus     0
# dtype: int64

# %%
# Check for duplicate rows in the DataFrame
duplicates = df_data.duplicated()

# Count the number of duplicate rows
num_duplicates = duplicates.sum()
print(f"Number of duplicate rows: {num_duplicates}")

duplicate_rows = df_data[duplicates]
print("Duplicate rows:")
print(duplicate_rows)
# Out:
# Number of duplicate rows: 0
# Duplicate rows:
# Empty DataFrame
# Columns: [CaseCode, Age, AgeGroup, Sex, DateSpecimen, DateResultRelease, DateRepConf, DateDied, DateRecover, RemovalType, DateRepRem, Admitted, RegionRes, ProvRes, CityMunRes, CityMuniPSGC, BarangayRes, BarangayPSGC, HealthStatus, Quarantined, DateOnset, Pregnanttab, ValidationStatus]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA is the process of analyzing datasets to summarize their main characteristics, often using visual methods. It helps in understanding the data distribution, spotting anomalies, and forming hypotheses for further analysis.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sorting the data by a specified column (AgeGroup) in descending order
df_sorted = df_data.sort_values(by='AgeGroup', ascending=False)

# Plotting the distribution of cases by AgeGroup (top 10)
sns.countplot(x='AgeGroup', data=df_sorted.head(100))  # Show top 10 AgeGroups
plt.title('Case Distribution by Age Group')
plt.xticks(rotation=45)  # Rotate x labels if needed for better visibility
plt.show()

# %%
region_cases = df_data['BarangayRes'].value_counts().head(10)
sns.barplot(x=region_cases.values, y=region_cases.index)
plt.title('Case Distribution by Region')
plt.show()

# %%
region_group = df_data.groupby(['BarangayRes','Sex']).size()
total_cases = df_data.shape[0]
case_rates = (region_group / total_cases) * 100

# Display top regions by case rate
df_graph = case_rates.sort_values(ascending=False).head(10)
print(df_graph)
# Out:
# BarangayRes   Sex
# POBLACION     FEMALE    8.403361
# BARORO        FEMALE    6.302521
# POBLACION     MALE      6.092437
# NAGSARABOAN   FEMALE    2.731092
# NAGSIMBAANAN  MALE      2.731092
# BARORO        MALE      2.310924
# QUIRINO       FEMALE    2.100840
# CABAROAN      FEMALE    2.100840
# NAGSARABOAN   MALE      2.100840
# NAGSIMBAANAN  FEMALE    1.890756
# dtype: float64

# %%
# Sort the values and plot the pie chart
df_graph.plot(kind='pie', autopct='%1.1f%%', shadow=True, startangle=90)

# Set the title and remove the y-label
plt.title('Top 5 Regions by Number of Cases')
plt.ylabel('')  # Removes the y-axis label which is not needed for a pie chart

# Display the pie chart
plt.show()

# %%
age_sex_group = df_data.groupby(['AgeGroup', 'Sex']).size().head(10)
age_sex_rates_1 = (age_sex_group / total_cases) * 100

# Display top Age-Sex groups by case rate
age_sex_rates_1.sort_values(ascending=False).head(10)
# Out:
# AgeGroup  Sex
# 25 to 29  FEMALE    10.924370
# 20 to 24  FEMALE     4.621849
# 25 to 29  MALE       4.201681
# 20 to 24  MALE       2.310924
# 15 to 19  MALE       1.890756
# 10 to 14  FEMALE     1.680672
#           MALE       1.680672
# 0 to 4    MALE       1.260504
# 15 to 19  FEMALE     1.260504
# 0 to 4    FEMALE     1.050420
# dtype: float64

# %%
# Plotting the pie chart
age_sex_rates_1.plot(kind='pie', autopct='%1.1f%%', shadow=True, startangle=90)

# Set the title and remove the y-label
plt.title('Top Sex cases by Number of Cases')
plt.ylabel('')  # Removes the y-axis label which is not needed for a pie chart

# Display the pie chart
plt.show()

# %%
# Convert the columns to datetime format
df_data['DateResultRelease'] = pd.to_datetime(df_data['DateResultRelease'], errors='coerce')
df_data['DateOnset'] = pd.to_datetime(df_data['DateOnset'], errors='coerce')
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\3549890139.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DateResultRelease'] = pd.to_datetime(df_data['DateResultRelease'], errors='coerce')
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\3549890139.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DateOnset'] = pd.to_datetime(df_data['DateOnset'], errors='coerce')

# %%
# Now perform the subtraction and calculate the number of days
df_data['DaysToResult'] = (df_data['DateResultRelease'] - df_data['DateOnset']).dt.days
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\2578393520.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['DaysToResult'] = (df_data['DateResultRelease'] - df_data['DateOnset']).dt.days

# %%
df_data[['DateResultRelease','DateOnset','DaysToResult']].head(10)
# Out:
#       DateResultRelease  DateOnset  DaysToResult
# 121          2022-01-21 2022-01-19             2
# 2736         2022-01-21 2022-01-03            18
# 4664         2022-01-21 2022-01-10            11
# 5051         2022-01-12 2022-01-05             7
# 8528         2022-01-12 2022-01-02            10
# 10600        2022-01-21 2022-01-09            12
# 10936        2022-01-12 2022-01-10             2
# 13898        2022-01-12 2022-01-10             2
# 15851        2022-01-21 2022-01-19             2
# 16376        2022-01-21 2022-01-09            12

# %%
df_data['IsPregnant'] = df_data['DateRecover'].apply(lambda x: 1 if x == 'Yes' else 0)
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\3378457119.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['IsPregnant'] = df_data['DateRecover'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
df_data[['IsPregnant','DateRecover']] .head(10)
# Out:
#        IsPregnant DateRecover
# 121             0  2022-01-19
# 2736            0  2022-01-19
# 4664            0  2022-01-19
# 5051            0  2022-01-19
# 8528            0  2022-01-19
# 10600           0  2022-01-19
# 10936           0  2022-01-19
# 13898           0  2022-01-19
# 15851           0  2022-01-19
# 16376           0  2022-01-19

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler = MinMaxScaler()
df_data['Age_scaled'] = scaler.fit_transform(df_data[['Age']]).astype(int).round()
# Out:
# C:\Users\HABER\AppData\Local\Temp\ipykernel_5716\331620460.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Age_scaled'] = scaler.fit_transform(df_data[['Age']]).astype(int).round()

# %%
df_data_cleaned = df_data.dropna(subset=['CaseCode'])

# %%
from sklearn.preprocessing import PolynomialFeatures

# Drop non-numerical columns (e.g., object and datetime columns)
X_numerical = df_data.select_dtypes(include=['int64', 'int32', 'float64', 'Int64'])  # Select numerical columns only

# Apply PolynomialFeatures on the numerical columns
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X_numerical)

# Check the shape of the transformed data
print(X_poly.shape)
# Out:
# (476, 15)

# %%
from sklearn.model_selection import train_test_split

# Selecting features and target
X = X_poly
y = df_data['AgeGroup']  # Assuming binary classification: 'Recovered' or 'Not Recovered'

# %%
# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#predict on the test set
y_pred = model.predict(X_test)

# %%
score_rf = round(accuracy_score(y_test, y_pred) *100, 2)
print("The accuracy score achieved using RF is: " + str(score_rf) + " %")
# Out:
# The accuracy score achieved using RF is: 88.81 %

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# Combine the actual and predicted values into a DataFrame
comparison_df_rf = pd.DataFrame({'Actual': y_test.reset_index(drop=True), 'Predicted': y_pred})

# Count the occurrences of each class in both actual and predicted for SVC
actual_counts_rf = comparison_df_rf['Actual'].value_counts().sort_index()
predicted_counts_rf = comparison_df_rf['Predicted'].value_counts().sort_index()

# Convert counts to percentages for SVC
actual_percentages_rf = (actual_counts_rf / actual_counts_rf.sum()) * 100
predicted_percentages_rf = (predicted_counts_rf / predicted_counts_rf.sum()) * 100

# Create a DataFrame for plotting SVC results
percentages_df_rf = pd.DataFrame({
    'Actual': actual_percentages_rf,
    'Predicted': predicted_percentages_rf
}).sort_values(by='Actual', ascending=False).head()

# Plot the SVC data
percentages_df_rf.plot(kind='bar', figsize=(10, 6), color=['#1f77b4', '#ff7f0e'])

# Add titles and labels for SVC
plt.title(' (Percentage) using rf')
plt.xlabel('BarangayRes')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.legend(title='Legend')
plt.show()

# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Define features and target
X = X_poly
y = df_data['AgeGroup']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the model (SVC or RandomForest)
model = SVC()  # or use RandomForestClassifier() if that's your intention

# Fit the model on training data
model.fit(X_train, y_train)

# Predict on test data
y_pred_svc = model.predict(X_test)

# Calculate and print accuracy
accuracy = round(accuracy_score(y_test, y_pred_svc) * 100, 2)
print("The accuracy score achieved using the model is: " + str(accuracy) + " %")
# Out:
# The accuracy score achieved using the model is: 17.48 %

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# Combine the actual and predicted values into a DataFrame
comparison_df_svc = pd.DataFrame({'Actual': y_test.reset_index(drop=True), 'Predicted': y_pred_svc})

# Count the occurrences of each class in both actual and predicted for SVC
actual_counts_svc = comparison_df_svc['Actual'].value_counts().sort_index()
predicted_counts_svc = comparison_df_svc['Predicted'].value_counts().sort_index()

# Convert counts to percentages for SVC
actual_percentages_svc = (actual_counts_svc / actual_counts_svc.sum()) * 100
predicted_percentages_svc = (predicted_counts_svc / predicted_counts_svc.sum()) * 100

# Create a DataFrame for plotting SVC results
percentages_df_svc = pd.DataFrame({
    'Actual': actual_percentages_svc,
    'Predicted': predicted_percentages_svc
}).sort_values(by='Actual', ascending=False)

# Plot the SVC data
percentages_df_svc.plot(kind='bar', figsize=(10, 6), color=['#1f77b4', '#ff7f0e'])

# Add titles and labels for SVC
plt.title('Comparison of Actual vs. Predicted BarangayRes (Percentage) using SVC')
plt.xlabel('BarangayRes')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.legend(title='Legend')
plt.show()

# Accuracy score
svc_accuracy = round(accuracy_score(y_test, y_pred_svc) * 100, 2)
print("The accuracy score achieved using SVC is: " + str(svc_accuracy) + " %")
# Out:
# The accuracy score achieved using SVC is: 17.48 %

# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Define features and target
X = X_poly
y = df_data['AgeGroup']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the KNN model
model = KNeighborsClassifier(n_neighbors=5)  # You can adjust n_neighbors as needed

# Fit the model on training data
model.fit(X_train, y_train)

# Predict on test data
y_pred_knn = model.predict(X_test)

# Calculate and print accuracy
accuracy = round(accuracy_score(y_test, y_pred_knn) * 100, 2)
print("The accuracy score achieved using KNN is: " + str(accuracy) + " %")
# Out:
# The accuracy score achieved using KNN is: 82.52 %

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

# Combine the actual and predicted values into a DataFrame
comparison_df_knn = pd.DataFrame({'Actual': y_test.reset_index(drop=True), 'Predicted': y_pred_knn})

# Count the occurrences of each class in both actual and predicted for KNN
actual_counts_knn = comparison_df_knn['Actual'].value_counts().sort_index()
predicted_counts_knn = comparison_df_knn['Predicted'].value_counts().sort_index()

# Convert counts to percentages for KNN
actual_percentages_knn = (actual_counts_knn / actual_counts_knn.sum()) * 100
predicted_percentages_knn = (predicted_counts_knn / predicted_counts_knn.sum()) * 100

# Create a DataFrame for plotting KNN results
percentages_df_knn = pd.DataFrame({
    'Actual': actual_percentages_knn,
    'Predicted': predicted_percentages_knn
}).sort_index()

# Select the top 10 age groups by actual counts
top_10_percentages_df_knn = percentages_df_knn.head(10)

# Plot the top 10 KNN data
top_10_percentages_df_knn.plot(kind='bar', figsize=(10, 6), color=['#1f77b4', '#ff7f0e'])

# Add titles and labels for KNN
plt.title('Top 10 Comparison of Actual vs. Predicted Age Groups (Percentage) using KNN')
plt.xlabel('Age Group')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.legend(title='Legend')
plt.show()

# Accuracy score
knn_accuracy = round(accuracy_score(y_test, y_pred_knn) * 100, 2)
print("The accuracy score achieved using KNN is: " + str(knn_accuracy) + " %")
# Out:
# The accuracy score achieved using KNN is: 82.52 %

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Define features and target
X = X_poly
y = df_data['AgeGroup']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the Decision Tree Classifier
model = DecisionTreeClassifier()

# Fit the model on training data
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Calculate and print accuracy
accuracy_dt = round(accuracy_score(y_test, y_pred) * 100, 2)
print("The accuracy score achieved using the Decision Tree Classifier is: " + str(accuracy) + " %")

# Combine actual and predicted values into a DataFrame
comparison_df = pd.DataFrame({'Actual': y_test.reset_index(drop=True), 'Predicted': y_pred})

# Count occurrences of each class
actual_counts = comparison_df['Actual'].value_counts().sort_index()
predicted_counts = comparison_df['Predicted'].value_counts().sort_index()

# Create a DataFrame for plotting
percentages_df = pd.DataFrame({
    'Actual': (actual_counts / actual_counts.sum()) * 100,
    'Predicted': (predicted_counts / predicted_counts.sum()) * 100
}).sort_index()

# Select the top 10 classes by actual counts
top_10_percentages_df = percentages_df.head(10)

# Plot the top 10 data
top_10_percentages_df.plot(kind='bar', figsize=(10, 6), color=['#1f77b4', '#ff7f0e'])

# Add titles and labels
plt.title('Top 10 Comparison of Actual vs. Predicted Age Groups using Decision Tree Classifier')
plt.xlabel('Age Group')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.legend(title='Legend')
plt.show()
# Out:
# The accuracy score achieved using the Decision Tree Classifier is: 82.52 %

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Define features and target
X = X_poly
y = df_data['AgeGroup']

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the neural network model
model = MLPClassifier(hidden_layer_sizes=(100,), max_iter=500, random_state=42)

# Fit the model on training data
model.fit(X_train, y_train)

# Predict on test data
y_pred_nn = model.predict(X_test)

# Calculate and print accuracy
nn = round(accuracy_score(y_test, y_pred_nn) * 100, 2)
print("The accuracy score achieved using the neural network model is: " + str(accuracy) + " %")
# Out:
# The accuracy score achieved using the neural network model is: 8.39 %

# %%
# Combine the actual and predicted values into a DataFrame
comparison_df_nn = pd.DataFrame({'Actual': y_test.reset_index(drop=True), 'Predicted': y_pred_nn})

# Count the occurrences of each class in both actual and predicted for NN
actual_counts_nn = comparison_df_nn['Actual'].value_counts().sort_index()
predicted_counts_nn = comparison_df_nn['Predicted'].value_counts().sort_index()

# Convert counts to percentages for NN
actual_percentages_nn = (actual_counts_nn / actual_counts_nn.sum()) * 100
predicted_percentages_nn = (predicted_counts_nn / predicted_counts_nn.sum()) * 100

# Create a DataFrame for plotting NN results
percentages_df_nn = pd.DataFrame({
    'Actual': actual_percentages_nn,
    'Predicted': predicted_percentages_nn
}).sort_index()

# Select the top 10 age groups by actual counts
top_10_percentages_df_nn = percentages_df_nn.head(10)

# Plot the top 10 NN data
top_10_percentages_df_nn.plot(kind='bar', figsize=(10, 6), color=['#1f77b4', '#ff7f0e'])

# Add titles and labels for NN
plt.title('Top 10 Comparison of Actual vs. Predicted Age Group (Percentage) using Neural Network')
plt.xlabel('Age Group')
plt.ylabel('Percentage')
plt.xticks(rotation=45)  # Rotate labels for better readability
plt.legend(title='Legend')
plt.show()

# %%
scores = [score_rf, svc_accuracy, knn_accuracy, accuracy_dt, nn]
algorithms = ["Random Forest", "Support Vector Machine", "K-Nearest Neighbors", "Decision Tree", "Neural Network"]    

# Print the accuracy scores for each algorithm
for i in range(len(algorithms)):
    print(f"The accuracy score achieved using {algorithms[i]} is: {scores[i]} %")
# Out:
# The accuracy score achieved using Random Forest is: 88.81 %
# The accuracy score achieved using Support Vector Machine is: 17.48 %
# The accuracy score achieved using K-Nearest Neighbors is: 82.52 %
# The accuracy score achieved using Decision Tree is: 100.0 %
# The accuracy score achieved using Neural Network is: 8.39 %

# %%
# Set the figure size
sns.set(rc={'figure.figsize':(15,8)})

# Create the barplot
sns.barplot(x=algorithms, y=scores)

# Add labels and title
plt.xlabel("Algorithms")
plt.ylabel("Accuracy Score (%)")
plt.title("Comparison of Accuracy Scores for Different Algorithms")

# Display the plot
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Example data preparation
# Assuming you have a DataFrame `df_data` with 'Age' as the target and other features as predictors

# Define features (X) and target (y)
X = df_data[['Age_scaled']]  # Replace with your features
y = df_data['Age']  # Replace with your target variable

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the linear regression model
model = LinearRegression()

# Fit the model on training data
model.fit(X_train, y_train)

# Predict on test data
y_pred = model.predict(X_test)

# Calculate mean squared error and R^2 score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print metrics
print("Mean Squared Error: ", mse)
print("R^2 Score: ", r2)

# Plotting the regression results
plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='blue', label='Actual')
plt.scatter(X_test, y_pred, color='orange', label='Predicted')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Regression Line')
plt.title('Regression Analysis: Actual vs. Predicted')
plt.xlabel('Features (Age_scaled)')
plt.ylabel('Target (Age)')
plt.legend()
plt.show()
# Out:
# Mean Squared Error:  329.7376720175618
# R^2 Score:  0.0965608222368044

# %%
# Step 1: Calculate Q1, Q3, and IQR
Q1 = df_data['Age'].quantile(0.25)
Q3 = df_data['Age'].quantile(0.75)
IQR = Q3 - Q1

# Step 2: Define outlier bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 3: Filter for outliers
outliers = df_data[(df_data['Age'] < lower_bound) | (df_data['Age'] > upper_bound)]

# Display outliers
print(f"Number of outliers: {len(outliers)}")
print(outliers)
# Out:
# Number of outliers: 0
# Empty DataFrame
# Columns: [CaseCode, Age, AgeGroup, Sex, DateSpecimen, DateResultRelease, DateRepConf, DateDied, DateRecover, RemovalType, DateRepRem, Admitted, RegionRes, ProvRes, CityMunRes, CityMuniPSGC, BarangayRes, BarangayPSGC, HealthStatus, Quarantined, DateOnset, Pregnanttab, ValidationStatus, DaysToResult, IsPregnant, Age_scaled]
# Index: []
#
# [0 rows x 26 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Create a box plot for the 'Age' column
plt.figure(figsize=(8, 6))
plt.boxplot(df_data['Age'].dropna(), vert=False)  # Drop NaN values for the plot
plt.title('Box Plot of Age')
plt.xlabel('Age')

# Show grid for better readability
plt.grid(axis='x')

plt.show()
